# %% [markdown]
# <a href="https://colab.research.google.com/github/davoutuk/WheelChooser/blob/master/BirdNET_Lite_JPRF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# basic calculation
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# audio processing
from scipy.io import wavfile as wavefile
from IPython.display import Audio
import subprocess
# !pip install resampy

# data import
from google.colab import drive
# Out:
# Requirement already satisfied: resampy in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from resampy) (2.0.2)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.11/dist-packages (from resampy) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.53->resampy) (0.43.0)

# %%
#get data drive from my google drive
drive.mount('/content/gdrive',force_remount=True)

#git clone BirdNET-Lite
if not os.path.exists('/content/BirdNET-Lite'):
   # !git clone https://github.com/kahst/BirdNET-Lite.git
# Out:
# Mounted at /content/gdrive

# %%
#direct to the python working directory
os.chdir('/content/BirdNET-Lite')
print('current path = ' + os.getcwd())
# Out:
# current path = /content/BirdNET-Lite

# %%
#
# For all .wav files in the whole folder
#
print('step 1')


# Set the path to the WAV directory
wav_dir = '/content/gdrive/MyDrive/BirdNET_WAV/*.WAV'
print('step 2')

# Set the path to the output directory
output_dir = '/content/gdrive/MyDrive/WAV_output'
print('step 3')

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
print('step 4')

# Loop through all the WAV files in the directory
for wav_file in glob.glob(wav_dir):
    # Get the name of the WAV file without the directory path or file extension
    wav_name = os.path.splitext(os.path.basename(wav_file))[0]
    print(wav_name)

    # Set the path for the output CSV file
    output_file = os.path.join(output_dir, f"{wav_name}_output.csv")

    # Run the BirdNET analysis on each file
    # !python3 analyze.py --i "$wav_file" --lat 51.3093 --lon -121.7945 --week 18 --o "BirdNET_output.txt" --min_conf 0.1

    # Read the results into a pandas DataFrame
    result = pd.read_table("BirdNET_output.txt", sep=";")

    # Save the results to a CSV file
    result.to_csv(output_file, index=False)

print('step 5')
# Out:
# step 1
# step 2
# step 3
# step 4
# 20250228_054100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749738703.162932   10184 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749738703.176394   10184 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: Created TensorFlow Lite delegate for select TF ops.
# INFO: TfLiteFlexDelegate delegate: 1 nodes delegated out of 182 nodes with 1 partitions.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# LOADING TF LITE MODEL... DONE!
# READING AUDIO DATA... DONE! READ 20 CHUNKS.
# ANALYZING AUDIO... DONE! Time 1.1 SECONDS
# WRITING RESULTS TO BirdNET_output.txt ... DONE! WROTE 0 RESULTS.
# 20250228_062500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749738731.288026   10325 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749738731.299716   10325 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: Created TensorFlow Lite delegate for select TF ops.
# INFO: TfLiteFlexDelegate delegate: 1 nodes delegated out of 182 nodes with 1 partitions.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# LOADING TF LITE MODEL... DONE!
# READING AUDIO DATA... DONE! READ 20 CHUNKS.
# ANALYZING AUDIO... DONE! Time 1.3 SECONDS
# WRITING RESULTS TO BirdNET_output.txt ... DONE! WROTE 2 RESULTS.
# 20250228_063600
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749738743.182005   10391 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749738743.200773   10391 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: Created TensorFlow Lite delegate for select TF ops.
# INFO: TfLiteFlexDelegate delegate: 1 nodes delegated out of 182 nodes with 1 partitions.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# LOADING TF LITE MODEL... DONE!
# READING AUDIO DATA... DONE! READ 20 CHUNKS.
# ANALYZING AUDIO... DONE! Time 1.1 SECONDS
# WRITING RESULTS TO BirdNET_output.txt ... DONE! WROTE 11 RESULTS.
# 20250228_061400
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749738757.911314   10469 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749738757.917955   10469 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: Created TensorFlow Lite delegate for select TF ops.
# INFO: TfLiteFlexDelegate delegate: 1 nodes delegated out of 182 nodes with 1 partitions.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# LOADING TF LITE MODEL... DONE!
# READING AUDIO DATA... DONE! READ 20 CHUNKS.
# ANALYZING AUDIO... DONE! Time 1.1 SECONDS
# WRITING RESULTS TO BirdNET_output.txt ... DONE! WROTE 0 RESULTS.
# 20250228_055200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749738769.721358   10538 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749738769.728075   10538 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: Created TensorFlow Lite delegate for select TF ops.
# INFO: TfLiteFlexDelegate delegate: 1 nodes delegated out of 182 nodes with 1 partitions.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# LOADING TF LITE MODEL... DONE!
# READING AUDIO DATA... DONE! READ 20 CHUNKS.
# ANALYZING AUDIO... DONE! Time 1.1 SECONDS
# WRITING RESULTS TO BirdNET_output.txt ... DONE! WROTE 0 RESULTS.
# 20250228_060300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749738781.179461   10601 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749738781.185915   10601 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: Created TensorFlow Lite delegate for select TF ops.
# INFO: TfLiteFlexDelegate delegate: 1 nodes delegated out of 182 nodes with 1 partitions.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# LOADING TF LITE MODEL... DONE!
# READING AUDIO DATA... DONE! READ 20 CHUNKS.
# ANALYZING AUDIO... DONE! Time 1.9 SECONDS
# WRITING RESULTS TO BirdNET_output.txt ... DONE! WROTE 0 RESULTS.
# step 5

# %%
#
# For single files
#

# !python3 analyze.py --i '../gdrive/MyDrive/WAV/190427_1118_COLO.wav' --lat 51.3093 --lon -121.7945 --week 18 --o 'BirdNET_output.txt' --min_conf 0.1

result = pd.read_table('BirdNET_output.txt', sep = ';')

# %%
# parameters to set while running BirdNET-Lite

#--i, Path to input file.
#--o, Path to output file. Defaults to result.csv.
#--lat, Recording location latitude. Set -1 to ignore.
#--lon, Recording location longitude. Set -1 to ignore.
#--week, Week of the year when the recording was made. Values in [1, 48] (4 weeks per month). Set -1 to ignore.
#--overlap, Overlap in seconds between extracted spectrograms. Values in [0.0, 2.9]. Defaults tp 0.0.
#--sensitivity, Detection sensitivity; Higher values result in higher sensitivity. Values in [0.5, 1.5]. Defaults to 1.0.
#--min_conf, Minimum confidence threshold. Values in [0.01, 0.99]. Defaults to 0.1.
#--custom_list, Path to text file containing a list of species. Not used if not provided.
